# %%
# order_book_sim_extended.py
# ---------------------------------------------------------
# Limit order book simulator with extended order types.
# Supported:
#   - Order types: limit, market, stop (market), stop-limit
#   - TIF: GTC (default), IOC, FOK
#   - Post-Only for limit orders (reject if it would cross)
# Matching:
#   - Price-time priority, partial fills
#   - Trades occur at the resting order's price
# Stops:
#   - Trigger on last trade price; if none yet, use best quotes
# Random flow:
#   - Generates a mix of these orders over time
# ---------------------------------------------------------

from __future__ import annotations
from dataclasses import dataclass
from collections import deque
import heapq
import itertools
import random
from typing import Deque, Dict, List, Optional, Tuple

# ---------- Configuration ----------
TICK_SIZE = 0.5
INIT_LEVELS = 6
INIT_QTY_RANGE = (20, 120)

ARRIVAL_STEPS = 140  # number of events

# Random order flow knobs
P_LIMIT = 0.70          # else market (for non-stop arrivals)
P_STOP = 0.10           # probability to create a stop-market
P_STOP_LIMIT = 0.10     # probability to create a stop-limit
P_POST_ONLY = 0.10      # for limit orders
TIF_WEIGHTS = {         # draw among these for all active orders
    "GTC": 0.70,
    "IOC": 0.20,
    "FOK": 0.10,
}

QTY_RANGE = (5, 80)
CROSSING_BIAS = 0.30    # chance a limit is placed to cross
SEED = 7
SHOW_LEVELS = 6

# ---------- Utilities ----------
_order_id = itertools.count(1)

def round_to_tick(price: float) -> float:
    """Snap a float price to the nearest tick."""
    ticks = int(round(price / TICK_SIZE))
    return ticks * TICK_SIZE


@dataclass
class Order:
    """Generic order record used for both active and resting orders."""
    id: int
    side: str              # 'buy' or 'sell'
    qty: int
    type: str              # 'limit', 'market', 'stop', 'stop_limit'
    price: Optional[float] # limit price (if applicable)
    ts: int                # event time (discrete integer)
    tif: str = "GTC"       # 'GTC', 'IOC', 'FOK'
    post_only: bool = False
    stop_price: Optional[float] = None  # for stop / stop-limit


class OrderBook:
    """
    Price-time priority LOB with:
    - FIFO queues per price
    - Min-heap for asks, max-heap for bids (via negative prices)
    - Stop orders stored off-book until triggered
    """

    def __init__(self):
        self.bids: Dict[float, Deque[Order]] = {}
        self.asks: Dict[float, Deque[Order]] = {}
        self._bid_heap: List[float] = []
        self._ask_heap: List[float] = []
        self.stop_orders: List[Order] = []  # waiting for trigger

        # trade record: (ts, price, qty, buy_id, sell_id)
        self.trades: List[Tuple[int, float, int, int, int]] = []
        self.last_trade_price: Optional[float] = None

    # ----- Best price helpers (with lazy cleanup) -----
    def _best_bid(self) -> Optional[float]:
        while self._bid_heap:
            p = -self._bid_heap[0]
            q = self.bids.get(p)
            if q and len(q) > 0:
                return p
            heapq.heappop(self._bid_heap)
        return None

    def _best_ask(self) -> Optional[float]:
        while self._ask_heap:
            p = self._ask_heap[0]
            q = self.asks.get(p)
            if q and len(q) > 0:
                return p
            heapq.heappop(self._ask_heap)
        return None

    # ----- Resting insertion -----
    def _rest(self, o: Order) -> None:
        """Add a limit order to the book (rest any remainder)."""
        assert o.type == "limit", "Only limit orders can rest on book."
        book = self.bids if o.side == "buy" else self.asks
        heap = self._bid_heap if o.side == "buy" else self._ask_heap
        price = round_to_tick(float(o.price))
        o.price = price
        if price not in book:
            book[price] = deque()
            heapq.heappush(heap, -price if o.side == "buy" else price)
        book[price].append(o)

    # ----- Liquidity check for FOK -----
    def _cumulative_liquidity(self, taker_side: str, limit_price: Optional[float]) -> int:
        """
        Return total opposing liquidity available at prices that would execute
        this taker order (side = taker side). For MARKET, limit_price is None.
        """
        if taker_side == "buy":
            prices = sorted(self.asks.keys())
            total = 0
            for p in prices:
                if limit_price is not None and p > limit_price:
                    break
                total += sum(q.qty for q in self.asks[p])
            return total
        else:
            prices = sorted(self.bids.keys(), reverse=True)
            total = 0
            for p in prices:
                if limit_price is not None and p < limit_price:
                    break
                total += sum(q.qty for q in self.bids[p])
            return total

    # ----- Stop management -----
    def queue_stop(self, o: Order) -> None:
        """Hold stop/stop-limit until trigger condition is met."""
        self.stop_orders.append(o)

    def collect_triggered_stops(self, ts: int) -> List[Order]:
        """Return and remove stops that should trigger now."""
        triggered: List[Order] = []
        if not self.stop_orders:
            return triggered

        bb = self._best_bid()
        ba = self._best_ask()

        # Use last trade price if available, else best quotes (touch trigger)
        ref_buy = self.last_trade_price if self.last_trade_price is not None else ba
        ref_sell = self.last_trade_price if self.last_trade_price is not None else bb

        keep: List[Order] = []
        for o in self.stop_orders:
            ok = False
            if o.side == "buy" and ref_buy is not None and o.stop_price is not None:
                ok = ref_buy >= o.stop_price
            elif o.side == "sell" and ref_sell is not None and o.stop_price is not None:
                ok = ref_sell <= o.stop_price

            if ok:
                # Convert to active order
                if o.type == "stop":
                    new_o = Order(o.id, o.side, o.qty, "market", None, ts, o.tif, False, None)
                else:
                    # stop-limit: price is the limit price already carried by 'o.price'
                    new_o = Order(o.id, o.side, o.qty, "limit", o.price, ts, o.tif, o.post_only, None)
                triggered.append(new_o)
            else:
                keep.append(o)

        self.stop_orders = keep
        return triggered

    # ----- Core matching engine -----
    def add(self, order: Order) -> List[Tuple[int, float, int, int, int]]:
        """
        Insert an order (active or stop). Returns list of trades:
        (ts, trade_price, trade_qty, buy_id, sell_id)
        """
        trades: List[Tuple[int, float, int, int, int]] = []

        def record(px: float, q: int, buy_id: int, sell_id: int):
            self.trades.append((order.ts, px, q, buy_id, sell_id))
            trades.append((order.ts, px, q, buy_id, sell_id))
            self.last_trade_price = px

        # Handle stop orders: keep off-book until triggered
        if order.type in ("stop", "stop_limit"):
            self.queue_stop(order)
            return trades  # no immediate trade

        # MARKET orders: always IOC-like by nature
        if order.type == "market":
            qty_left = order.qty
            if order.tif == "FOK":
                need = order.qty
                avail = self._cumulative_liquidity(order.side, None)
                if avail < need:
                    return trades  # reject (no partial fills for FOK)

            if order.side == "buy":
                while qty_left > 0:
                    best_ask = self._best_ask()
                    if best_ask is None:
                        break
                    q = self.asks[best_ask][0]
                    traded = min(qty_left, q.qty)
                    q.qty -= traded
                    qty_left -= traded
                    record(best_ask, traded, buy_id=order.id, sell_id=q.id)
                    if q.qty == 0:
                        self.asks[best_ask].popleft()
            else:
                while qty_left > 0:
                    best_bid = self._best_bid()
                    if best_bid is None:
                        break
                    q = self.bids[best_bid][0]
                    traded = min(qty_left, q.qty)
                    q.qty -= traded
                    qty_left -= traded
                    record(best_bid, traded, buy_id=q.id, sell_id=order.id)
                    if q.qty == 0:
                        self.bids[best_bid].popleft()
            return trades  # leftover discarded

        # LIMIT orders
        assert order.price is not None
        px = round_to_tick(float(order.price))
        order.price = px

        # Post-Only: if the order would cross, reject it entirely
        if order.post_only:
            bb = self._best_bid()
            ba = self._best_ask()
            would_cross = (
                (order.side == "buy" and ba is not None and px >= ba) or
                (order.side == "sell" and bb is not None and px <= bb)
            )
            if would_cross:
                return trades  # silently canceled (post-only)

        # FOK pre-check: is there enough opposing liquidity at/better than px?
        if order.tif == "FOK":
            limit_for_taker = px
            avail = self._cumulative_liquidity(order.side, limit_for_taker)
            if avail < order.qty:
                return trades  # reject entirely

        qty_left = order.qty

        if order.side == "buy":
            # Try to cross as long as best ask <= limit price
            while qty_left > 0:
                best_ask = self._best_ask()
                if best_ask is None or px < best_ask:
                    break
                q = self.asks[best_ask][0]
                traded = min(qty_left, q.qty)
                q.qty -= traded
                qty_left -= traded
                record(best_ask, traded, buy_id=order.id, sell_id=q.id)
                if q.qty == 0:
                    self.asks[best_ask].popleft()

            # Rest remainder if allowed by TIF
            if qty_left > 0 and order.tif != "IOC":
                self._rest(Order(order.id, order.side, qty_left, "limit", px, order.ts, order.tif, order.post_only))

        else:
            while qty_left > 0:
                best_bid = self._best_bid()
                if best_bid is None or px > best_bid:
                    break
                q = self.bids[best_bid][0]
                traded = min(qty_left, q.qty)
                q.qty -= traded
                qty_left -= traded
                record(best_bid, traded, buy_id=q.id, sell_id=order.id)
                if q.qty == 0:
                    self.bids[best_bid].popleft()

            if qty_left > 0 and order.tif != "IOC":
                self._rest(Order(order.id, order.side, qty_left, "limit", px, order.ts, order.tif, order.post_only))

        return trades

    # ----- Rendering & stats -----
    def top_of_book(self) -> Tuple[Optional[float], int, Optional[float], int]:
        bb = self._best_bid()
        ba = self._best_ask()
        bid_sz = sum(o.qty for o in self.bids.get(bb, [])) if bb is not None else 0
        ask_sz = sum(o.qty for o in self.asks.get(ba, [])) if ba is not None else 0
        return bb, bid_sz, ba, ask_sz

    def depth(self, side: str, n: int) -> List[Tuple[float, int]]:
        if side == "buy":
            prices = sorted(self.bids.keys(), reverse=True)
            book = self.bids
        else:
            prices = sorted(self.asks.keys())
            book = self.asks
        out = []
        for p in prices[:n]:
            out.append((p, sum(o.qty for o in book[p])))
        return out

    def mid(self) -> Optional[float]:
        bb, _, ba, _ = self.top_of_book()
        if bb is None or ba is None:
            return None
        return round_to_tick((bb + ba) / 2.0)

    def render(self, levels: int = 5) -> str:
        left = self.depth("buy", levels)
        right = self.depth("sell", levels)
        max_rows = max(len(left), len(right))
        left += [("", "")] * (max_rows - len(left))
        right += [("", "")] * (max_rows - len(right))
        lines = ["  BID (px x qty)        |        ASK (px x qty)"]
        for i in range(max_rows):
            lp = f"{left[i][0]:>7}" if left[i][0] != "" else "       "
            lq = f"{left[i][1]:>5}" if left[i][1] != "" else "     "
            rp = f"{right[i][0]:>7}" if right[i][0] != "" else "       "
            rq = f"{right[i][1]:>5}" if right[i][1] != "" else "     "
            lines.append(f" {lp} x {lq}        |        {rp} x {rq}")
        lines.append(f"\n  (Queued stops: {len(self.stop_orders)})")
        return "\n".join(lines)


# ---------- Initialization & random flow ----------
def initialize_random_book(book: OrderBook, mid: float, ts: int = 0) -> None:
    """Fill symmetric random depth around an initial mid."""
    for i in range(1, INIT_LEVELS + 1):
        bid_px = round_to_tick(mid - i * TICK_SIZE)
        ask_px = round_to_tick(mid + i * TICK_SIZE)
        bid_qty = random.randint(*INIT_QTY_RANGE)
        ask_qty = random.randint(*INIT_QTY_RANGE)
        bid = Order(next(_order_id), "buy", bid_qty, "limit", bid_px, ts)
        ask = Order(next(_order_id), "sell", ask_qty, "limit", ask_px, ts)
        book.add(bid)
        book.add(ask)


def draw_tif() -> str:
    r = random.random()
    acc = 0.0
    for k, w in TIF_WEIGHTS.items():
        acc += w
        if r <= acc:
            return k
    return "GTC"


def sample_arrival(book: OrderBook, ts: int) -> Order:
    """
    Generate a random incoming order making use of the extended features.
    - Sometimes emits stop or stop-limit orders.
    - Otherwise emits limit/market with IOC/FOK/GTC and optional Post-Only.
    """
    side = "buy" if random.random() < 0.5 else "sell"
    qty = random.randint(*QTY_RANGE)
    tif = draw_tif()

    bb, _, ba, _ = book.top_of_book()
    if bb is None and ba is None:
        anchor = 100.0
        bb = round_to_tick(anchor - TICK_SIZE)
        ba = round_to_tick(anchor + TICK_SIZE)

    # Decide stop vs regular
    r = random.random()
    if r < P_STOP:
        # STOP MARKET
        if side == "buy":
            # trigger above current ask
            stop_px = round_to_tick((ba if ba is not None else 100.0) + random.randint(1, 3)*TICK_SIZE)
        else:
            stop_px = round_to_tick((bb if bb is not None else 100.0) - random.randint(1, 3)*TICK_SIZE)
        return Order(next(_order_id), side, qty, "stop", None, ts, tif, False, stop_px)

    elif r < P_STOP + P_STOP_LIMIT:
        # STOP-LIMIT: trigger at stop, place limit at (often) the stop level
        if side == "buy":
            stop_px = round_to_tick((ba if ba is not None else 100.0) + random.randint(1, 3)*TICK_SIZE)
            limit_px = stop_px  # could also be stop_px + n*ticks
        else:
            stop_px = round_to_tick((bb if bb is not None else 100.0) - random.randint(1, 3)*TICK_SIZE)
            limit_px = stop_px
        return Order(next(_order_id), side, qty, "stop_limit", limit_px, ts, tif, False, stop_px)

    # Regular (non-stop): choose market vs limit
    typ = "limit" if random.random() < P_LIMIT else "market"

    if typ == "market":
        return Order(next(_order_id), side, qty, "market", None, ts, tif, False, None)

    # Limit: propose a price around mid, occasionally crossing
    mid = book.mid()
    if mid is None:
        mid = (bb + ba) / 2 if bb is not None and ba is not None else 100.0

    cross = random.random() < CROSSING_BIAS
    delta = random.randint(0, 4)
    if side == "buy":
        px = round_to_tick(mid - delta * TICK_SIZE)
        if cross and ba is not None:
            px = max(px, ba)  # touch/cross
    else:
        px = round_to_tick(mid + delta * TICK_SIZE)
        if cross and bb is not None:
            px = min(px, bb)

    post_only = (random.random() < P_POST_ONLY)
    return Order(next(_order_id), side, qty, "limit", px, ts, tif, post_only, None)


# ---------- Driver ----------
def simulate(steps: int = ARRIVAL_STEPS, seed: int = SEED) -> None:
    random.seed(seed)
    ob = OrderBook()
    start_mid = 100.0
    initialize_random_book(ob, start_mid, ts=0)

    print("\n--- INITIAL BOOK ---")
    print(ob.render(SHOW_LEVELS))
    bb, bs, ba, asz = ob.top_of_book()
    print(f"\nTop of book: bid {bb} x {bs} | ask {ba} x {asz}\n")

    t = 0
    for k in range(steps):
        t += 1
        incoming = sample_arrival(ob, ts=t)
        hdr = f"[t={t:03d}] IN: {incoming.type.upper():>10} {incoming.side.upper():>4} qty={incoming.qty}"
        if incoming.type in ("limit", "stop_limit"):
            hdr += f" @ {incoming.price}"
        if incoming.stop_price is not None:
            hdr += f" (stop={incoming.stop_price})"
        if incoming.tif != "GTC":
            hdr += f" [{incoming.tif}]"
        if incoming.post_only:
            hdr += " [POST-ONLY]"
        print(hdr)

        trades = ob.add(incoming)
        if trades:
            for (ts_, px, q, buy_id, sell_id) in trades:
                print(f"     -> TRADE ts={ts_} px={px} qty={q} (buy#{buy_id} vs sell#{sell_id})")
        else:
            if incoming.type in ("stop", "stop_limit"):
                print("     -> queued as STOP order")
            else:
                print("     -> no trade")

        # After processing, check for any stops that should trigger now.
        # Keep triggering in case cascading trades change prices further.
        while True:
            triggered = ob.collect_triggered_stops(ts=t)  # use same event time for simplicity
            if not triggered:
                break
            for trig in triggered:
                print(f"     TRIGGERED: {trig.type.upper()} {trig.side.upper()} qty={trig.qty}"
                      + (f" @ {trig.price}" if trig.type == "limit" else " (MKT)")
                      + (f" [{trig.tif}]" if trig.tif != "GTC" else ""))
                t_trades = ob.add(trig)
                if t_trades:
                    for (ts_, px, q, buy_id, sell_id) in t_trades:
                        print(f"         -> TRADE ts={ts_} px={px} qty={q} (buy#{buy_id} vs sell#{sell_id})")

        bb, bs, ba, asz = ob.top_of_book()
        mid = ob.mid()
        print(f"     Top: bid {bb} x {bs} | ask {ba} x {asz} | mid={mid}")

        if k % 10 == 0 or k < 3:
            print(ob.render(SHOW_LEVELS))

    print("\n--- FINAL BOOK ---")
    print(ob.render(SHOW_LEVELS))
    print(f"\nTotal trades: {len(ob.trades)}")


if __name__ == "__main__":
    simulate()
# Out:
# --- INITIAL BOOK ---
#   BID (px x qty)        |        ASK (px x qty)
#     99.5 x    61        |          100.5 x    39
#     99.0 x    70        |          101.0 x   103
#     98.5 x    26        |          101.5 x    29
#     98.0 x    88        |          102.0 x    32
#     97.5 x    66        |          102.5 x    94
#     97.0 x    27        |          103.0 x    84
#
#   (Queued stops: 0)
#
# Top of book: bid 99.5 x 61 | ask 100.5 x 39
#
# [t=001] IN:       STOP  BUY qty=16 (stop=101.0)
#      -> queued as STOP order
#      Top: bid 99.5 x 61 | ask 100.5 x 39 | mid=100.0
#   BID (px x qty)        |        ASK (px x qty)
#     99.5 x    61        |          100.5 x    39
#     99.0 x    70        |          101.0 x   103
#     98.5 x    26        |          101.5 x    29
#     98.0 x    88        |          102.0 x    32
#     97.5 x    66        |          102.5 x    94
#     97.0 x    27        |          103.0 x    84
#
#   (Queued stops: 1)
# [t=002] IN: STOP_LIMIT SELL qty=12 @ 99.0 (stop=99.0) [IOC]
#      -> queued as STOP order
#      Top: bid 99.5 x 61 | ask 100.5 x 39 | mid=100.0
#   BID (px x qty)        |        ASK (px x qty)
#     99.5 x    61        |          100.5 x    39
#     99.0 x    70        |          101.0 x   103
#     98.5 x    26        |          101.5 x    29
#     98.0 x    88        |          102.0 x    32
#     97.5 x    66        |          102.5 x    94
#     97.0 x    27        |          103.0 x    84
#
#   (Queued stops: 2)
# [t=003] IN:      LIMIT SELL qty=79 @ 100.0 [FOK]
#      -> no trade
#      Top: bid 99.5 x 61 | ask 100.5 x 39 | mid=100.0
#   BID (px x qty)        |        ASK (px x qty)
#     99.5 x    61        |          100.5 x    39
#     99.0 x    70        |          101.0 x   103
#     98.5 x    26        |          101.5 x    29
#     98.0 x    88        |          102.0 x    32
#     97.5 x    66        |          102.5 x    94
#     97.0 x    27        |          103.0 x    84
#
#   (Queued stops: 2)
# [t=004] IN: STOP_LIMIT  BUY qty=58 @ 101.5 (stop=101.5)
#      -> queued as STOP order
#      Top: bid 99.5 x 61 | ask 100.5 x 39 | mid=100.0
# [t=005] IN:      LIMIT SELL qty=28 @ 99.5
#      -> TRADE ts=5 px=99.5 qty=28 (buy#1 vs sell#17)
#      Top: bid 99.5 x 33 | ask 100.5 x 39 | mid=100.0
# [t=006] IN:      LIMIT SELL qty=68 @ 101.5
#      -> no trade
#      Top: bid 99.5 x 33 | ask 100.5 x 39 | mid=100.0
# [t=007] IN:      LIMIT  BUY qty=28 @ 99.0
#      -> no trade
#      Top: bid 99.5 x 33 | ask 100.5 x 39 | mid=100.0
# [t=008] IN:     MARKET  BUY qty=14
#      -> TRADE ts=8 px=100.5 qty=14 (buy#20 vs sell#2)
#      Top: bid 99.5 x 33 | ask 100.5 x 25 | mid=100.0
# [t=009] IN:      LIMIT  BUY qty=67 @ 99.0
#      -> no trade
#      Top: bid 99.5 x 33 | ask 100.5 x 25 | mid=100.0
# [t=010] IN:     MARKET  BUY qty=68
#      -> TRADE ts=10 px=100.5 qty=25 (buy#22 vs sell#2)
#      -> TRADE ts=10 px=101.0 qty=43 (buy#22 vs sell#4)
#      TRIGGERED: MARKET BUY qty=16 (MKT)
#          -> TRADE ts=10 px=101.0 qty=16 (buy#13 vs sell#4)
#      Top: bid 99.5 x 33 | ask 101.0 x 44 | mid=100.0
# [t=011] IN:       STOP SELL qty=65 (stop=98.0)
#      -> queued as STOP order
#      Top: bid 99.5 x 33 | ask 101.0 x 44 | mid=100.0
#   BID (px x qty)        |        ASK (px x qty)
#     99.5 x    33        |          100.5 x     0
#     99.0 x   165        |          101.0 x    44
#     98.5 x    26        |          101.5 x    97
#     98.0 x    88        |          102.0 x    32
#     97.5 x    66        |          102.5 x    94
#     97.0 x    27        |          103.0 x    84
#
#   (Queued stops: 3)
# [t=012] IN:      LIMIT SELL qty=78 @ 101.0 [FOK] [POST-ONLY]
#      -> no trade
#      Top: bid 99.5 x 33 | ask 101.0 x 44 | mid=100.0
# [t=013] IN:      LIMIT  BUY qty=26 @ 101.0
#      -> TRADE ts=13 px=101.0 qty=26 (buy#25 vs sell#4)
#      Top: bid 99.5 x 33 | ask 101.0 x 18 | mid=100.0
# [t=014] IN:      LIMIT SELL qty=68 @ 101.5
#      -> no trade
#      Top: bid 99.5 x 33 | ask 101.0 x 18 | mid=100.0
# [t=015] IN:      LIMIT  BUY qty=58 @ 101.0 [FOK]
#      -> no trade
#      Top: bid 99.5 x 33 | ask 101.0 x 18 | mid=100.0
# [t=016] IN:      LIMIT  BUY qty=34 @ 101.0
#      -> TRADE ts=16 px=101.0 qty=18 (buy#28 vs sell#4)
#      Top: bid 101.0 x 16 | ask 101.5 x 165 | mid=101.0
# [t=017] IN: STOP_LIMIT  BUY qty=77 @ 103.0 (stop=103.0)
#      -> queued as STOP order
#      Top: bid 101.0 x 16 | ask 101.5 x 165 | mid=101.0
# [t=018] IN:     MARKET SELL qty=11
#      -> TRADE ts=18 px=101.0 qty=11 (buy#28 vs sell#30)
#      Top: bid 101.0 x 5 | ask 101.5 x 165 | mid=101.0
# [t=019] IN:      LIMIT SELL qty=76 @ 101.0
#      -> TRADE ts=19 px=101.0 qty=5 (buy#28 vs sell#31)
#      Top: bid 99.5 x 33 | ask 101.5 x 165 | mid=100.5
# [t=020] IN:      LIMIT SELL qty=61 @ 99.5
#      -> TRADE ts=20 px=99.5 qty=33 (buy#1 vs sell#32)
#      Top: bid 99.0 x 165 | ask 99.5 x 28 | mid=99.0
# [t=021] IN:      LIMIT SELL qty=8 @ 100.0
#      -> no trade
#      Top: bid 99.0 x 165 | ask 99.5 x 28 | mid=99.0
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           99.5 x    28
#     99.5 x     0        |          100.0 x     8
#     99.0 x   165        |          100.5 x     0
#     98.5 x    26        |          101.0 x    71
#     98.0 x    88        |          101.5 x   165
#     97.5 x    66        |          102.0 x    32
#
#   (Queued stops: 4)
# [t=022] IN:      LIMIT  BUY qty=19 @ 99.0 [IOC]
#      -> no trade
#      Top: bid 99.0 x 165 | ask 99.5 x 28 | mid=99.0
# [t=023] IN:      LIMIT SELL qty=38 @ 99.0
#      -> TRADE ts=23 px=99.0 qty=38 (buy#3 vs sell#35)
#      TRIGGERED: LIMIT SELL qty=12 @ 99.0 [IOC]
#          -> TRADE ts=23 px=99.0 qty=12 (buy#3 vs sell#14)
#      Top: bid 99.0 x 115 | ask 99.5 x 28 | mid=99.0
# [t=024] IN:      LIMIT SELL qty=8 @ 99.0 [IOC]
#      -> TRADE ts=24 px=99.0 qty=8 (buy#3 vs sell#36)
#      Top: bid 99.0 x 107 | ask 99.5 x 28 | mid=99.0
# [t=025] IN:     MARKET SELL qty=50 [IOC]
#      -> TRADE ts=25 px=99.0 qty=12 (buy#3 vs sell#37)
#      -> TRADE ts=25 px=99.0 qty=28 (buy#19 vs sell#37)
#      -> TRADE ts=25 px=99.0 qty=10 (buy#21 vs sell#37)
#      Top: bid 99.0 x 57 | ask 99.5 x 28 | mid=99.0
# [t=026] IN:     MARKET  BUY qty=33
#      -> TRADE ts=26 px=99.5 qty=28 (buy#38 vs sell#32)
#      -> TRADE ts=26 px=100.0 qty=5 (buy#38 vs sell#33)
#      Top: bid 99.0 x 57 | ask 100.0 x 3 | mid=99.5
# [t=027] IN:      LIMIT  BUY qty=35 @ 98.5 [IOC]
#      -> no trade
#      Top: bid 99.0 x 57 | ask 100.0 x 3 | mid=99.5
# [t=028] IN: STOP_LIMIT SELL qty=40 @ 97.5 (stop=97.5)
#      -> queued as STOP order
#      Top: bid 99.0 x 57 | ask 100.0 x 3 | mid=99.5
# [t=029] IN:      LIMIT SELL qty=62 @ 99.5 [IOC]
#      -> no trade
#      Top: bid 99.0 x 57 | ask 100.0 x 3 | mid=99.5
# [t=030] IN:     MARKET  BUY qty=30
#      -> TRADE ts=30 px=100.0 qty=3 (buy#42 vs sell#33)
#      -> TRADE ts=30 px=101.5 qty=27 (buy#42 vs sell#6)
#      TRIGGERED: LIMIT BUY qty=58 @ 101.5
#          -> TRADE ts=30 px=101.5 qty=2 (buy#16 vs sell#6)
#          -> TRADE ts=30 px=101.5 qty=56 (buy#16 vs sell#18)
#      Top: bid 99.0 x 57 | ask 101.5 x 80 | mid=100.0
# [t=031] IN:     MARKET SELL qty=5
#      -> TRADE ts=31 px=99.0 qty=5 (buy#21 vs sell#43)
#      Top: bid 99.0 x 52 | ask 101.5 x 80 | mid=100.0
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           99.5 x     0
#     99.5 x     0        |          100.0 x     0
#     99.0 x    52        |          100.5 x     0
#     98.5 x    26        |          101.0 x    71
#     98.0 x    88        |          101.5 x    80
#     97.5 x    66        |          102.0 x    32
#
#   (Queued stops: 3)
# [t=032] IN:     MARKET  BUY qty=20 [FOK]
#      -> TRADE ts=32 px=101.5 qty=12 (buy#44 vs sell#18)
#      -> TRADE ts=32 px=101.5 qty=8 (buy#44 vs sell#26)
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=033] IN:      LIMIT  BUY qty=27 @ 98.5
#      -> no trade
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=034] IN: STOP_LIMIT SELL qty=15 @ 98.5 (stop=98.5) [IOC]
#      -> queued as STOP order
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=035] IN:      LIMIT  BUY qty=80 @ 98.5 [FOK]
#      -> no trade
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=036] IN:       STOP  BUY qty=75 (stop=103.0)
#      -> queued as STOP order
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=037] IN: STOP_LIMIT SELL qty=72 @ 98.5 (stop=98.5) [IOC]
#      -> queued as STOP order
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=038] IN:      LIMIT SELL qty=32 @ 101.0
#      -> no trade
#      Top: bid 99.0 x 52 | ask 101.5 x 60 | mid=100.0
# [t=039] IN:     MARKET  BUY qty=21
#      -> TRADE ts=39 px=101.5 qty=21 (buy#51 vs sell#26)
#      Top: bid 99.0 x 52 | ask 101.5 x 39 | mid=100.0
# [t=040] IN:      LIMIT SELL qty=71 @ 102.0
#      -> no trade
#      Top: bid 99.0 x 52 | ask 101.5 x 39 | mid=100.0
# [t=041] IN:      LIMIT SELL qty=28 @ 99.0
#      -> TRADE ts=41 px=99.0 qty=28 (buy#21 vs sell#53)
#      Top: bid 99.0 x 24 | ask 101.5 x 39 | mid=100.0
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           99.5 x     0
#     99.5 x     0        |          100.0 x     0
#     99.0 x    24        |          100.5 x     0
#     98.5 x    53        |          101.0 x   103
#     98.0 x    88        |          101.5 x    39
#     97.5 x    66        |          102.0 x   103
#
#   (Queued stops: 6)
# [t=042] IN:      LIMIT SELL qty=46 @ 102.0 [POST-ONLY]
#      -> no trade
#      Top: bid 99.0 x 24 | ask 101.5 x 39 | mid=100.0
# [t=043] IN:      LIMIT  BUY qty=10 @ 100.0 [IOC]
#      -> no trade
#      Top: bid 99.0 x 24 | ask 101.5 x 39 | mid=100.0
# [t=044] IN: STOP_LIMIT SELL qty=69 @ 98.0 (stop=98.0)
#      -> queued as STOP order
#      Top: bid 99.0 x 24 | ask 101.5 x 39 | mid=100.0
# [t=045] IN:      LIMIT  BUY qty=73 @ 99.0 [IOC]
#      -> no trade
#      Top: bid 99.0 x 24 | ask 101.5 x 39 | mid=100.0
# [t=046] IN: STOP_LIMIT SELL qty=30 @ 98.5 (stop=98.5) [IOC]
#      -> queued as STOP order
#      Top: bid 99.0 x 24 | ask 101.5 x 39 | mid=100.0
# [t=047] IN:      LIMIT  BUY qty=45 @ 100.0
#      -> no trade
#      Top: bid 100.0 x 45 | ask 101.5 x 39 | mid=101.0
# [t=048] IN:     MARKET  BUY qty=51
#      -> TRADE ts=48 px=101.5 qty=39 (buy#60 vs sell#26)
#      -> TRADE ts=48 px=102.0 qty=12 (buy#60 vs sell#8)
#      Top: bid 100.0 x 45 | ask 102.0 x 137 | mid=101.0
# [t=049] IN:     MARKET  BUY qty=17
#      -> TRADE ts=49 px=102.0 qty=17 (buy#61 vs sell#8)
#      Top: bid 100.0 x 45 | ask 102.0 x 120 | mid=101.0
# [t=050] IN:      LIMIT SELL qty=25 @ 102.0 [IOC]
#      -> no trade
#      Top: bid 100.0 x 45 | ask 102.0 x 120 | mid=101.0
# [t=051] IN:     MARKET SELL qty=7
#      -> TRADE ts=51 px=100.0 qty=7 (buy#59 vs sell#63)
#      Top: bid 100.0 x 38 | ask 102.0 x 120 | mid=101.0
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           99.5 x     0
#    100.0 x    38        |          100.0 x     0
#     99.5 x     0        |          100.5 x     0
#     99.0 x    24        |          101.0 x   103
#     98.5 x    53        |          101.5 x     0
#     98.0 x    88        |          102.0 x   120
#
#   (Queued stops: 8)
# [t=052] IN:      LIMIT  BUY qty=71 @ 100.5
#      -> no trade
#      Top: bid 100.5 x 71 | ask 102.0 x 120 | mid=101.0
# [t=053] IN:      LIMIT  BUY qty=38 @ 99.5
#      -> no trade
#      Top: bid 100.5 x 71 | ask 102.0 x 120 | mid=101.0
# [t=054] IN:      LIMIT SELL qty=38 @ 102.0 [POST-ONLY]
#      -> no trade
#      Top: bid 100.5 x 71 | ask 102.0 x 158 | mid=101.0
# [t=055] IN:       STOP  BUY qty=28 (stop=102.5)
#      -> queued as STOP order
#      Top: bid 100.5 x 71 | ask 102.0 x 158 | mid=101.0
# [t=056] IN:      LIMIT SELL qty=38 @ 102.5 [POST-ONLY]
#      -> no trade
#      Top: bid 100.5 x 71 | ask 102.0 x 158 | mid=101.0
# [t=057] IN:      LIMIT SELL qty=58 @ 101.5 [FOK]
#      -> no trade
#      Top: bid 100.5 x 71 | ask 102.0 x 158 | mid=101.0
# [t=058] IN:      LIMIT SELL qty=38 @ 101.5
#      -> no trade
#      Top: bid 100.5 x 71 | ask 102.0 x 158 | mid=101.0
# [t=059] IN:     MARKET SELL qty=27
#      -> TRADE ts=59 px=100.5 qty=27 (buy#64 vs sell#71)
#      Top: bid 100.5 x 44 | ask 102.0 x 158 | mid=101.0
# [t=060] IN:      LIMIT  BUY qty=7 @ 99.5 [IOC]
#      -> no trade
#      Top: bid 100.5 x 44 | ask 102.0 x 158 | mid=101.0
# [t=061] IN:     MARKET SELL qty=60
#      -> TRADE ts=61 px=100.5 qty=44 (buy#64 vs sell#73)
#      -> TRADE ts=61 px=100.0 qty=16 (buy#59 vs sell#73)
#      Top: bid 100.0 x 22 | ask 102.0 x 158 | mid=101.0
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           99.5 x     0
#    100.5 x     0        |          100.0 x     0
#    100.0 x    22        |          100.5 x     0
#     99.5 x    38        |          101.0 x   103
#     99.0 x    24        |          101.5 x    38
#     98.5 x    53        |          102.0 x   158
#
#   (Queued stops: 9)
# [t=062] IN:      LIMIT SELL qty=44 @ 101.5
#      -> no trade
#      Top: bid 100.0 x 22 | ask 102.0 x 158 | mid=101.0
# [t=063] IN:       STOP  BUY qty=11 (stop=103.5) [IOC]
#      -> queued as STOP order
#      Top: bid 100.0 x 22 | ask 102.0 x 158 | mid=101.0
# [t=064] IN:       STOP SELL qty=37 (stop=98.5)
#      -> queued as STOP order
#      Top: bid 100.0 x 22 | ask 102.0 x 158 | mid=101.0
# [t=065] IN:      LIMIT SELL qty=69 @ 100.0
#      -> TRADE ts=65 px=100.0 qty=22 (buy#59 vs sell#77)
#      Top: bid 99.0 x 24 | ask 102.0 x 158 | mid=100.5
# [t=066] IN:     MARKET  BUY qty=5
#      -> TRADE ts=66 px=102.0 qty=3 (buy#78 vs sell#8)
#      -> TRADE ts=66 px=102.0 qty=2 (buy#78 vs sell#52)
#      Top: bid 99.0 x 24 | ask 102.0 x 153 | mid=100.5
# [t=067] IN:      LIMIT SELL qty=36 @ 99.0
#      -> TRADE ts=67 px=99.0 qty=24 (buy#21 vs sell#79)
#      Top: bid 98.5 x 53 | ask 99.0 x 12 | mid=99.0
# [t=068] IN:     MARKET  BUY qty=69
#      -> TRADE ts=68 px=99.0 qty=12 (buy#80 vs sell#79)
#      -> TRADE ts=68 px=102.0 qty=57 (buy#80 vs sell#52)
#      Top: bid 98.5 x 53 | ask 102.0 x 96 | mid=100.0
# [t=069] IN:      LIMIT  BUY qty=16 @ 102.0 [POST-ONLY]
#      -> no trade
#      Top: bid 98.5 x 53 | ask 102.0 x 96 | mid=100.0
# [t=070] IN:     MARKET SELL qty=24
#      -> TRADE ts=70 px=98.5 qty=24 (buy#5 vs sell#82)
#      TRIGGERED: LIMIT SELL qty=15 @ 98.5 [IOC]
#          -> TRADE ts=70 px=98.5 qty=2 (buy#5 vs sell#46)
#          -> TRADE ts=70 px=98.5 qty=13 (buy#45 vs sell#46)
#      TRIGGERED: LIMIT SELL qty=72 @ 98.5 [IOC]
#          -> TRADE ts=70 px=98.5 qty=14 (buy#45 vs sell#49)
#      TRIGGERED: LIMIT SELL qty=30 @ 98.5 [IOC]
#      TRIGGERED: MARKET SELL qty=37 (MKT)
#          -> TRADE ts=70 px=98.0 qty=37 (buy#7 vs sell#76)
#      TRIGGERED: MARKET SELL qty=65 (MKT)
#          -> TRADE ts=70 px=98.0 qty=51 (buy#7 vs sell#23)
#          -> TRADE ts=70 px=97.5 qty=14 (buy#9 vs sell#23)
#      TRIGGERED: LIMIT SELL qty=69 @ 98.0
#      TRIGGERED: LIMIT SELL qty=40 @ 97.5
#          -> TRADE ts=70 px=97.5 qty=40 (buy#9 vs sell#40)
#      Top: bid 97.5 x 12 | ask 98.0 x 69 | mid=98.0
# [t=071] IN:      LIMIT  BUY qty=46 @ 97.5 [IOC] [POST-ONLY]
#      -> no trade
#      Top: bid 97.5 x 12 | ask 98.0 x 69 | mid=98.0
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           98.0 x    69
#    100.5 x     0        |           99.0 x     0
#    100.0 x     0        |           99.5 x     0
#     99.5 x    38        |          100.0 x    47
#     99.0 x     0        |          100.5 x     0
#     98.5 x     0        |          101.0 x   103
#
#   (Queued stops: 4)
# [t=072] IN:     MARKET SELL qty=70
#      -> TRADE ts=72 px=97.5 qty=12 (buy#9 vs sell#84)
#      -> TRADE ts=72 px=97.0 qty=27 (buy#11 vs sell#84)
#      Top: bid None x 0 | ask 98.0 x 69 | mid=None
# [t=073] IN:     MARKET  BUY qty=72 [IOC]
#      -> TRADE ts=73 px=98.0 qty=69 (buy#85 vs sell#56)
#      -> TRADE ts=73 px=102.0 qty=3 (buy#85 vs sell#52)
#      Top: bid None x 0 | ask 102.0 x 93 | mid=None
# [t=074] IN:     MARKET  BUY qty=79 [IOC]
#      -> TRADE ts=74 px=102.0 qty=9 (buy#86 vs sell#52)
#      -> TRADE ts=74 px=102.0 qty=46 (buy#86 vs sell#54)
#      -> TRADE ts=74 px=102.0 qty=24 (buy#86 vs sell#66)
#      Top: bid None x 0 | ask 102.0 x 14 | mid=None
# [t=075] IN: STOP_LIMIT SELL qty=15 @ 99.0 (stop=99.0)
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.0 x 14 | mid=None
# [t=076] IN:      LIMIT SELL qty=53 @ 100.5 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask 102.0 x 14 | mid=None
# [t=077] IN:      LIMIT  BUY qty=13 @ 100.0 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask 102.0 x 14 | mid=None
# [t=078] IN:     MARKET  BUY qty=14 [IOC]
#      -> TRADE ts=78 px=102.0 qty=14 (buy#90 vs sell#66)
#      Top: bid None x 0 | ask 102.5 x 132 | mid=None
# [t=079] IN:      LIMIT  BUY qty=63 @ 100.0
#      -> no trade
#      Top: bid None x 0 | ask 102.5 x 132 | mid=None
# [t=080] IN:      LIMIT SELL qty=14 @ 102.0
#      -> no trade
#      Top: bid None x 0 | ask 102.5 x 132 | mid=None
# [t=081] IN:      LIMIT  BUY qty=12 @ 102.5
#      -> TRADE ts=81 px=102.5 qty=12 (buy#93 vs sell#10)
#      TRIGGERED: MARKET BUY qty=28 (MKT)
#          -> TRADE ts=81 px=102.5 qty=28 (buy#67 vs sell#10)
#      Top: bid None x 0 | ask 102.5 x 92 | mid=None
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           98.0 x     0
#    100.5 x     0        |           99.0 x     0
#    100.0 x    63        |           99.5 x     0
#     99.5 x    38        |          100.0 x    47
#     99.0 x     0        |          100.5 x     0
#     98.5 x     0        |          101.0 x   103
#
#   (Queued stops: 4)
# [t=082] IN:     MARKET SELL qty=64
#      -> no trade
#      Top: bid None x 0 | ask 102.5 x 92 | mid=None
# [t=083] IN:      LIMIT SELL qty=44 @ 102.0 [FOK]
#      -> no trade
#      Top: bid None x 0 | ask 102.5 x 92 | mid=None
# [t=084] IN:     MARKET  BUY qty=39
#      -> TRADE ts=84 px=102.5 qty=39 (buy#96 vs sell#10)
#      Top: bid None x 0 | ask 102.5 x 53 | mid=None
# [t=085] IN:     MARKET  BUY qty=16
#      -> TRADE ts=85 px=102.5 qty=15 (buy#97 vs sell#10)
#      -> TRADE ts=85 px=102.5 qty=1 (buy#97 vs sell#68)
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=086] IN: STOP_LIMIT  BUY qty=70 @ 103.5 (stop=103.5)
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=087] IN: STOP_LIMIT  BUY qty=67 @ 103.5 (stop=103.5)
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=088] IN: STOP_LIMIT SELL qty=56 @ 99.0 (stop=99.0)
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=089] IN:       STOP  BUY qty=20 (stop=103.5) [IOC]
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=090] IN: STOP_LIMIT SELL qty=20 @ 99.5 (stop=99.5) [FOK]
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=091] IN:       STOP SELL qty=42 (stop=99.0)
#      -> queued as STOP order
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
#   BID (px x qty)        |        ASK (px x qty)
#    101.0 x     0        |           98.0 x     0
#    100.5 x     0        |           99.0 x     0
#    100.0 x    63        |           99.5 x     0
#     99.5 x    38        |          100.0 x    47
#     99.0 x     0        |          100.5 x     0
#     98.5 x     0        |          101.0 x   103
#
#   (Queued stops: 10)
# [t=092] IN:     MARKET SELL qty=80
#      -> no trade
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=093] IN:      LIMIT SELL qty=40 @ 100.5
#      -> no trade
#      Top: bid None x 0 | ask 102.5 x 37 | mid=None
# [t=094] IN:     MARKET  BUY qty=45
#      -> TRADE ts=94 px=102.5 qty=37 (buy#106 vs sell#68)
#      -> TRADE ts=94 px=103.0 qty=8 (buy#106 vs sell#12)
#      TRIGGERED: LIMIT BUY qty=77 @ 103.0
#          -> TRADE ts=94 px=103.0 qty=76 (buy#29 vs sell#12)
#      TRIGGERED: MARKET BUY qty=75 (MKT)
#      Top: bid 103.0 x 1 | ask None x 0 | mid=None
# [t=095] IN:      LIMIT SELL qty=56 @ 100.0 [FOK]
#      -> TRADE ts=95 px=103.0 qty=1 (buy#29 vs sell#107)
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=096] IN:      LIMIT  BUY qty=22 @ 99.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=097] IN:     MARKET  BUY qty=41
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=098] IN:      LIMIT  BUY qty=35 @ 100.5 [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=099] IN:      LIMIT SELL qty=68 @ 101.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=100] IN:      LIMIT  BUY qty=16 @ 98.0
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=101] IN:      LIMIT  BUY qty=57 @ 100.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
#   BID (px x qty)        |        ASK (px x qty)
#    103.0 x     0        |           98.0 x     0
#    101.0 x     0        |           99.0 x     0
#    100.5 x    92        |           99.5 x     0
#    100.0 x    63        |          100.0 x   102
#     99.5 x    60        |          100.5 x    40
#     99.0 x     0        |          101.0 x   103
#
#   (Queued stops: 8)
# [t=102] IN:      LIMIT SELL qty=51 @ 100.5 [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=103] IN:     MARKET SELL qty=54
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=104] IN:     MARKET SELL qty=7
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=105] IN:       STOP SELL qty=80 (stop=98.0)
#      -> queued as STOP order
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=106] IN: STOP_LIMIT SELL qty=62 @ 99.0 (stop=99.0)
#      -> queued as STOP order
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=107] IN:      LIMIT  BUY qty=18 @ 98.5 [FOK] [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=108] IN:     MARKET SELL qty=5 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=109] IN:      LIMIT SELL qty=43 @ 100.0 [FOK] [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=110] IN:     MARKET  BUY qty=79
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=111] IN:     MARKET  BUY qty=73
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
#   BID (px x qty)        |        ASK (px x qty)
#    103.0 x     0        |           98.0 x     0
#    101.0 x     0        |           99.0 x     0
#    100.5 x    92        |           99.5 x     0
#    100.0 x    63        |          100.0 x   145
#     99.5 x    60        |          100.5 x    91
#     99.0 x     0        |          101.0 x   103
#
#   (Queued stops: 10)
# [t=112] IN:      LIMIT SELL qty=36 @ 101.0 [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=113] IN:      LIMIT  BUY qty=58 @ 98.5 [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=114] IN:      LIMIT  BUY qty=58 @ 100.5 [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=115] IN:      LIMIT  BUY qty=30 @ 100.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=116] IN:     MARKET SELL qty=28 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=117] IN:       STOP  BUY qty=23 (stop=101.0) [FOK]
#      -> queued as STOP order
#      TRIGGERED: MARKET BUY qty=23 (MKT) [FOK]
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=118] IN:      LIMIT SELL qty=23 @ 101.0
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=119] IN: STOP_LIMIT SELL qty=26 @ 98.0 (stop=98.0)
#      -> queued as STOP order
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=120] IN:     MARKET SELL qty=9
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=121] IN:       STOP SELL qty=61 (stop=98.5)
#      -> queued as STOP order
#      Top: bid None x 0 | ask None x 0 | mid=None
#   BID (px x qty)        |        ASK (px x qty)
#    103.0 x     0        |           98.0 x     0
#    101.0 x     0        |           99.0 x     0
#    100.5 x   180        |           99.5 x     0
#    100.0 x    63        |          100.0 x   145
#     99.5 x    60        |          100.5 x    91
#     99.0 x     0        |          101.0 x   162
#
#   (Queued stops: 12)
# [t=122] IN: STOP_LIMIT  BUY qty=58 @ 101.0 (stop=101.0) [FOK]
#      -> queued as STOP order
#      TRIGGERED: LIMIT BUY qty=58 @ 101.0 [FOK]
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=123] IN:      LIMIT  BUY qty=44 @ 99.0 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=124] IN:      LIMIT  BUY qty=46 @ 98.5 [POST-ONLY]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=125] IN:       STOP  BUY qty=13 (stop=101.0) [IOC]
#      -> queued as STOP order
#      TRIGGERED: MARKET BUY qty=13 (MKT) [IOC]
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=126] IN:     MARKET SELL qty=48
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=127] IN:     MARKET  BUY qty=45 [FOK]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=128] IN:      LIMIT SELL qty=13 @ 101.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=129] IN:      LIMIT SELL qty=68 @ 101.0
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=130] IN:      LIMIT SELL qty=35 @ 100.0
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=131] IN:       STOP  BUY qty=25 (stop=101.0)
#      -> queued as STOP order
#      TRIGGERED: MARKET BUY qty=25 (MKT)
#      Top: bid None x 0 | ask None x 0 | mid=None
#   BID (px x qty)        |        ASK (px x qty)
#    103.0 x     0        |           98.0 x     0
#    101.0 x    58        |           99.0 x     0
#    100.5 x   180        |           99.5 x     0
#    100.0 x    63        |          100.0 x   180
#     99.5 x    60        |          100.5 x    91
#     99.0 x     0        |          101.0 x   230
#
#   (Queued stops: 12)
# [t=132] IN:     MARKET  BUY qty=74
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=133] IN:      LIMIT SELL qty=38 @ 101.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=134] IN:     MARKET  BUY qty=63
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=135] IN:      LIMIT SELL qty=20 @ 99.5 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=136] IN:      LIMIT  BUY qty=36 @ 99.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=137] IN:     MARKET  BUY qty=36
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=138] IN:     MARKET SELL qty=9
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=139] IN:      LIMIT SELL qty=52 @ 99.5
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
# [t=140] IN:      LIMIT  BUY qty=70 @ 100.0 [IOC]
#      -> no trade
#      Top: bid None x 0 | ask None x 0 | mid=None
#
# --- FINAL BOOK ---
#   BID (px x qty)        |        ASK (px x qty)
#    103.0 x     0        |           98.0 x     0
#    101.0 x    58        |           99.0 x     0
#    100.5 x   180        |           99.5 x    52
#    100.0 x    63        |          100.0 x   180
#     99.5 x    96        |          100.5 x    91
#     99.0 x     0        |          101.0 x   230
#
#   (Queued stops: 12)
#
# Total trades: 65
