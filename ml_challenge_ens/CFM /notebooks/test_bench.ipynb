# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pygwalker as pyg
from tensorflow.keras.layers import Input, Embedding, GRU, Dense, Concatenate, Flatten
from tensorflow.keras.models import Model
import numpy as np
# Out:
# 2024-11-12 16:16:54.961845: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# importation des différents fichiers dans l'environnement 
X_test = pd.read_csv("X_test_m4HAPAP.csv")
X_train = pd.read_csv("X_train_N1UvY30.csv")
y_train = pd.read_csv("y_train_or6m3Ta.csv")

# %%
# Variables catégorielles à encoder
categorical_columns = ['venue', 'action', 'side']

# Variables numériques
numeric_columns = ['price', 'bid', 'ask', 'bid_size', 'ask_size', 'flux']

# Encoding 
for col in categorical_columns:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col])
    X_test[col] = le.transform(X_test[col])


X_train['trade'] = X_train['trade'].astype(int)  
X_test['trade'] = X_test['trade'].astype(int)

# Transformation logarithmique pour 'bid_size' et 'ask_size'
X_train['log_bid_size'] = np.log(np.abs(X_train['bid_size'] + 1))
X_train['log_ask_size'] = np.log(np.abs(X_train['ask_size'] + 1))
X_train['log_flux'] = np.log(np.abs(X_train['flux'])+1) * np.sign(X_train['flux']) 

X_test['log_bid_size'] = np.log(np.abs(X_test['bid_size'] + 1))
X_test['log_ask_size'] = np.log(np.abs(X_test['ask_size'] + 1))
X_test['log_flux'] = np.log(np.abs(X_test['flux'])+1) * np.sign(X_train['flux'])

# Sélection des colonnes nécessaires pour le modèle
selected_columns = ['venue', 'action', 'trade',  'bid', 'ask', 'price', 'log_bid_size', 'log_ask_size', 'log_flux']

# %%
def group_by_observation(X_train, selected_columns, sequence_length=100):
    grouped = X_train.groupby('obs_id')

    # Préallocation d'un tableau pour stocker toutes les séquences
    num_groups = len(grouped)
    sequences = np.zeros((num_groups, sequence_length, len(selected_columns)))  # Shape: (num_groups, sequence_length, num_features)
    
    for i, (_, group) in enumerate(grouped):
        # Prendre les `sequence_length` premiers événements si plus
        sequence = group[selected_columns].values[:sequence_length]
        
        # Si moins de `sequence_length` événements, on applique du padding (remplissage avec des zéros)
        if len(sequence) < sequence_length:
            sequences[i, :len(sequence)] = sequence  # Remplir les lignes avec les données existantes
            # Les lignes restantes sont déjà initialisées à zéro
        else:
            sequences[i] = sequence  # Remplacer par la séquence complète

    return sequences

# Utilisation de la fonction
sequences = group_by_observation(X_train, selected_columns)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, GRU, Dense, Bidirectional, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Configuration de base
embedding_dim = 8
gru_units = 64
sequence_length = 100  # 100 événements
num_features = 9  # Dimensions des vecteurs d'entrées

# Dimensions des embeddings (hypothétiques)
num_unique_venues = 6  # nombre d'items possibles pour 'venue'
num_unique_actions = 3  # nombre d'items possibles pour 'action'
num_unique_trades = 2  # nombre d'items possibles pour 'trade'

# Entrée unique pour le tenseur avec les dimensions (num_observations, 100, nombre_de_features)
input_tensor = Input(shape=(sequence_length, num_features), name='input_tensor')

# Supposons que les 3 premières features sont des catégories
venue_embedding = Embedding(input_dim=num_unique_venues, output_dim=embedding_dim)(input_tensor[:, :, 0])  # 'venue'
action_embedding = Embedding(input_dim=num_unique_actions, output_dim=embedding_dim)(input_tensor[:, :, 1])  # 'action'

# On concatène les embeddings et les autres features
# Ici, nous assumons que les features restantes sont continues et déjà sous forme de tenseur 2D
continuous_features = input_tensor[:, :, 2:]  # toutes les autres features (bid, ask, etc.)

# Concatenation des embeddings et des features continues
features = tf.keras.layers.Concatenate(axis=-1)([
    venue_embedding, action_embedding,  continuous_features
])

# Utilisation d'une couche GRU bidirectionnelle
gru_output = Bidirectional(GRU(gru_units, return_sequences=False))(features)

# Ajout d'une première couche dense
dense_output1 = Dense(64, activation='selu')(gru_output)
dense_output1 = BatchNormalization()(dense_output1)  # Normalisation de lot
dense_output1 = Dropout(0.5)(dense_output1)  # Dropout

# Couche de sortie
output = Dense(24, activation='softmax')(dense_output1)  # 24 classes pour la sortie


# Création du modèle
model = Model(inputs=input_tensor, outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=3e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Résumé du modèle
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_tensor        │ (None, 100, 9)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 100)       │          0 │ input_tensor[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 100)       │          0 │ input_tensor[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 100, 8)    │         48 │ get_item[0][0]    │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 100, 8)    │         24 │ get_item_1[0][0]  │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 100, 7)    │          0 │ input_tensor[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 100, 23)   │          0 │ embedding[0][0],  │
# │ (Concatenate)       │                   │            │ embedding_1[0][0… │
# │                     │                   │            │ get_item_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 128)       │     34,176 │ concatenate[0][0] │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      8,256 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64)        │        256 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 24)        │      1,560 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 44,320 (173.12 KB)
#  Trainable params: 44,192 (172.62 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
model= model

# %%
from tensorflow.keras.utils import to_categorical
# Exemple de labels générés aléatoirement (à remplacer par tes vraies catégories cibles)
num_observations = sequences.shape[0]
Y= to_categorical(y_train['eqt_code_cat'], num_classes=24)

# %%
# Entraînement du modèle
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model.fit(sequences, Y, batch_size=1000, epochs=(10_000 * 1000) // num_observations, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Epoch 1/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - accuracy: 0.0993 - loss: 3.1862 - val_accuracy: 0.2007 - val_loss: 2.4170
# Epoch 2/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.2418 - loss: 2.2837 - val_accuracy: 0.2096 - val_loss: 2.4851
# Epoch 3/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 197s 1s/step - accuracy: 0.2968 - loss: 2.0835 - val_accuracy: 0.3224 - val_loss: 1.9704
# Epoch 4/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.3360 - loss: 1.9595 - val_accuracy: 0.3027 - val_loss: 2.0658
# Epoch 5/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.3562 - loss: 1.8998 - val_accuracy: 0.3412 - val_loss: 1.9833
# Epoch 6/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 208s 1s/step - accuracy: 0.3716 - loss: 1.8460 - val_accuracy: 0.3984 - val_loss: 1.7588
# Epoch 7/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 201s 1s/step - accuracy: 0.3915 - loss: 1.7926 - val_accuracy: 0.4034 - val_loss: 1.7263
# Epoch 8/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.4019 - loss: 1.7577 - val_accuracy: 0.4080 - val_loss: 1.7391
# Epoch 9/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.4083 - loss: 1.7311 - val_accuracy: 0.4186 - val_loss: 1.7165
# Epoch 10/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 210s 1s/step - accuracy: 0.4212 - loss: 1.6924 - val_accuracy: 0.4294 - val_loss: 1.6792
# Epoch 11/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.4366 - loss: 1.6487 - val_accuracy: 0.4495 - val_loss: 1.6145
# Epoch 12/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.4449 - loss: 1.6245 - val_accuracy: 0.4493 - val_loss: 1.5836
# Epoch 13/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 219s 2s/step - accuracy: 0.4529 - loss: 1.6013 - val_accuracy: 0.4737 - val_loss: 1.5334
# Epoch 14/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 222s 2s/step - accuracy: 0.4651 - loss: 1.5684 - val_accuracy: 0.4367 - val_loss: 1.6413
# Epoch 15/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.4702 - loss: 1.5505 - val_accuracy: 0.4493 - val_loss: 1.6097
# Epoch 16/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.4767 - loss: 1.5305 - val_accuracy: 0.4824 - val_loss: 1.5100
# Epoch 17/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 4714s 33s/step - accuracy: 0.4809 - loss: 1.5054 - val_accuracy: 0.5070 - val_loss: 1.4333
# Epoch 18/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.4923 - loss: 1.4774 - val_accuracy: 0.4820 - val_loss: 1.4886
# Epoch 19/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.4987 - loss: 1.4616 - val_accuracy: 0.4672 - val_loss: 1.6087
# Epoch 20/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.5057 - loss: 1.4345 - val_accuracy: 0.5075 - val_loss: 1.4526
# Epoch 21/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 195s 1s/step - accuracy: 0.5135 - loss: 1.4148 - val_accuracy: 0.4803 - val_loss: 1.5276
# Epoch 22/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.5160 - loss: 1.4064 - val_accuracy: 0.5111 - val_loss: 1.4188
# Epoch 23/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.5276 - loss: 1.3728 - val_accuracy: 0.5222 - val_loss: 1.3712
# Epoch 24/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.5338 - loss: 1.3566 - val_accuracy: 0.5396 - val_loss: 1.3155
# Epoch 25/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.5401 - loss: 1.3304 - val_accuracy: 0.5151 - val_loss: 1.3908
# Epoch 26/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.5449 - loss: 1.3192 - val_accuracy: 0.5344 - val_loss: 1.3445
# Epoch 27/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 199s 1s/step - accuracy: 0.5509 - loss: 1.3053 - val_accuracy: 0.5359 - val_loss: 1.3399
# Epoch 28/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.5558 - loss: 1.2880 - val_accuracy: 0.5552 - val_loss: 1.2743
# Epoch 29/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.5613 - loss: 1.2817 - val_accuracy: 0.5630 - val_loss: 1.2641
# Epoch 30/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.5651 - loss: 1.2607 - val_accuracy: 0.5612 - val_loss: 1.2761
# Epoch 31/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.5692 - loss: 1.2501 - val_accuracy: 0.5552 - val_loss: 1.2731
# Epoch 32/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.5738 - loss: 1.2391 - val_accuracy: 0.5746 - val_loss: 1.2388
# Epoch 33/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 188s 1s/step - accuracy: 0.5786 - loss: 1.2227 - val_accuracy: 0.5425 - val_loss: 1.3337
# Epoch 34/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 361s 2s/step - accuracy: 0.5819 - loss: 1.2123 - val_accuracy: 0.5917 - val_loss: 1.1963
# Epoch 35/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.5842 - loss: 1.2082 - val_accuracy: 0.5666 - val_loss: 1.2640
# Epoch 36/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.5924 - loss: 1.1874 - val_accuracy: 0.5919 - val_loss: 1.1857
# Epoch 37/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.5904 - loss: 1.1918 - val_accuracy: 0.5869 - val_loss: 1.2158
# Epoch 38/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.5948 - loss: 1.1757 - val_accuracy: 0.5826 - val_loss: 1.2050
# Epoch 39/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.5979 - loss: 1.1654 - val_accuracy: 0.5921 - val_loss: 1.1826
# Epoch 40/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 213s 1s/step - accuracy: 0.5980 - loss: 1.1634 - val_accuracy: 0.6029 - val_loss: 1.1553
# Epoch 41/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 205s 1s/step - accuracy: 0.6026 - loss: 1.1552 - val_accuracy: 0.5993 - val_loss: 1.1529
# Epoch 42/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - accuracy: 0.6041 - loss: 1.1532 - val_accuracy: 0.5814 - val_loss: 1.2020
# Epoch 43/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - accuracy: 0.6058 - loss: 1.1421 - val_accuracy: 0.5899 - val_loss: 1.2151
# Epoch 44/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - accuracy: 0.6089 - loss: 1.1368 - val_accuracy: 0.5957 - val_loss: 1.1952
# Epoch 45/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 209s 1s/step - accuracy: 0.6140 - loss: 1.1237 - val_accuracy: 0.5989 - val_loss: 1.1734
# Epoch 46/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.6113 - loss: 1.1275 - val_accuracy: 0.5928 - val_loss: 1.1811
# Epoch 47/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.6105 - loss: 1.1261 - val_accuracy: 0.5723 - val_loss: 1.2610
# Epoch 48/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.6152 - loss: 1.1203 - val_accuracy: 0.6133 - val_loss: 1.1193
# Epoch 49/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.6183 - loss: 1.1086 - val_accuracy: 0.6159 - val_loss: 1.1229
# Epoch 50/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 322s 2s/step - accuracy: 0.6198 - loss: 1.1051 - val_accuracy: 0.5989 - val_loss: 1.1626
# Epoch 51/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 272s 2s/step - accuracy: 0.6193 - loss: 1.1027 - val_accuracy: 0.6127 - val_loss: 1.1236
# Epoch 52/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.6192 - loss: 1.1075 - val_accuracy: 0.6009 - val_loss: 1.1578
# Epoch 53/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.6239 - loss: 1.0992 - val_accuracy: 0.6053 - val_loss: 1.1383
# Epoch 54/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.6260 - loss: 1.0863 - val_accuracy: 0.6158 - val_loss: 1.1094
# Epoch 55/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.6274 - loss: 1.0858 - val_accuracy: 0.6197 - val_loss: 1.1073
# Epoch 56/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.6302 - loss: 1.0786 - val_accuracy: 0.6115 - val_loss: 1.1459
# Epoch 57/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - accuracy: 0.6260 - loss: 1.0815 - val_accuracy: 0.6145 - val_loss: 1.1140
# Epoch 58/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 313s 2s/step - accuracy: 0.6294 - loss: 1.0781 - val_accuracy: 0.6137 - val_loss: 1.1147
# Epoch 59/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 0.6341 - loss: 1.0719 - val_accuracy: 0.6186 - val_loss: 1.1102
# Epoch 60/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.6308 - loss: 1.0699 - val_accuracy: 0.6124 - val_loss: 1.1276
# Epoch 61/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 261s 2s/step - accuracy: 0.6338 - loss: 1.0667 - val_accuracy: 0.6165 - val_loss: 1.1161
# Epoch 62/62
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 219s 2s/step - accuracy: 0.6334 - loss: 1.0659 - val_accuracy: 0.6170 - val_loss: 1.1168

# %%
from joblib import dump, load

# %%
dump(model, 'model_ML_ENS,3.modele')
# Out:
# ['model_ML_ENS,3.modele']

# %%
sequences_test = group_by_observation(X_test, selected_columns)

# %%
predictions = model.predict(sequences_test)
# Out:
# 2550/2550 ━━━━━━━━━━━━━━━━━━━━ 105s 40ms/step

# %%
y_predict_adjusted = np.argmax(predictions, axis=1)
df_prediction = pd.DataFrame(data = {'eqt_code_cat':y_predict_adjusted})

# %%
df_prediction.to_csv('y_prediction7.csv')

# %%
list_ = [True, False ]

# %%
a= map(int, list_)
